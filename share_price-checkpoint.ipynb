# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\vijay\anaconda3\lib\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\vijay\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vijay\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vijay\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vijay\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vijay\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijay\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vijay\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijay\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\vijay\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
from datetime import datetime
end =datetime.now()
start = datetime(end.year-20,end.month,end.day)

# %%
stock = 'SAIL.NS'
steel_authority = yf.download(stock ,start,end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
steel_authority.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker        SAIL.NS    SAIL.NS    SAIL.NS    SAIL.NS   SAIL.NS
# Date
# 2005-02-18  40.597099  41.460869  40.309176  40.949004  70507505
# 2005-02-21  40.149216  41.076965  39.989259  40.949001  45278070
# 2005-02-22  40.821033  41.012981  39.829300  40.117224  69117025
# 2005-02-23  40.661072  41.236916  40.341158  40.629081  62926835
# 2005-02-24  40.629086  41.108957  40.469129  40.501119  44041865

# %%
steel_authority.shape
# Out:
# (4938, 5)

# %%
steel_authority.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker      SAIL.NS      SAIL.NS      SAIL.NS      SAIL.NS       SAIL.NS
# count   4938.000000  4938.000000  4938.000000  4938.000000  4.938000e+03
# mean      76.753923    78.382171    75.276169    76.926084  2.989761e+07
# std       38.092883    38.912311    37.311879    38.224533  2.793726e+07
# min       17.534628    18.050353    17.319743    18.050353  0.000000e+00
# 25%       47.212625    48.164200    46.209362    47.251731  1.171330e+07
# 50%       66.331169    67.914938    65.176950    66.411953  2.145831e+07
# 75%      100.995655   103.210770    98.926973   101.029411  3.899992e+07
# max      200.610550   204.270709   196.915535   202.109448  3.229646e+08

# %%
steel_authority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4938 entries, 2005-02-18 to 2025-02-18
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, SAIL.NS)   4938 non-null   float64
#  1   (High, SAIL.NS)    4938 non-null   float64
#  2   (Low, SAIL.NS)     4938 non-null   float64
#  3   (Open, SAIL.NS)    4938 non-null   float64
#  4   (Volume, SAIL.NS)  4938 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 231.5 KB

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\vijay\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vijay\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vijay\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
steel_authority.isna().sum()
# Out:
# Price   Ticker
# Close   SAIL.NS    0
# High    SAIL.NS    0
# Low     SAIL.NS    0
# Open    SAIL.NS    0
# Volume  SAIL.NS    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(15,5))
steel_authority['Close'].plot()
plt.xlabel("years")
plt.ylabel("Close")
plt.title("Closing Price Of Steel Authority")
# Out:
# Text(0.5, 1.0, 'Closing Price Of Steel Authority')

# %%
def plot_graph(figsize, values ,column_name):
    plt.figure(figsize = figsize)
    values.plot()
    plt.xlabel("years")
    plt.ylabel(column_name)
    plt.title(f"{column_name} Of Steel Authority")

# %%
steel_authority.columns
# Out:
# MultiIndex([( 'Close', 'SAIL.NS'),
#             (  'High', 'SAIL.NS'),
#             (   'Low', 'SAIL.NS'),
#             (  'Open', 'SAIL.NS'),
#             ('Volume', 'SAIL.NS')],
#            names=['Price', 'Ticker'])

# %%
for  column in steel_authority.columns:
    plot_graph((15,5),steel_authority[column],column)

# %%
import pandas as pd

# %%
for i in range(2004,2026):
    print(i,list(steel_authority.index.year).count(i))
# Out:
# 2004 0
# 2005 218
# 2006 247
# 2007 248
# 2008 246
# 2009 243
# 2010 250
# 2011 246
# 2012 245
# 2013 248
# 2014 244
# 2015 246
# 2016 246
# 2017 248
# 2018 246
# 2019 243
# 2020 251
# 2021 248
# 2022 248
# 2023 245
# 2024 246
# 2025 36

# %%
steel_authority['MA_for_246_days']=steel_authority['Close'].rolling(246).mean()

# %%
steel_authority['MA_for_246_days']
# Out:
# Date
# 2005-02-18           NaN
# 2005-02-21           NaN
# 2005-02-22           NaN
# 2005-02-23           NaN
# 2005-02-24           NaN
#                  ...
# 2025-02-12    132.622206
# 2025-02-13    132.556550
# 2025-02-14    132.472777
# 2025-02-17    132.375157
# 2025-02-18    132.274321
# Name: MA_for_246_days, Length: 4938, dtype: float64

# %%
plot_graph((15,5),steel_authority['MA_for_246_days'],'MA_for_246_days')

# %%
plot_graph((15,5),steel_authority[['Close','MA_for_246_days']],'MA_for_246_days')

# %%
steel_authority['MA_for_100_days']=steel_authority['Close'].rolling(100).mean()
plot_graph((15,5),steel_authority[['Close','MA_for_100_days']],'MA_for_100_days')

# %%
plot_graph((15,5),steel_authority[['Close','MA_for_100_days','MA_for_246_days']],'MA')

# %%
steel_authority['percentage_change_cp']=steel_authority['Close'].pct_change()
steel_authority[['Close','percentage_change_cp']].head()
# Out:
# Price           Close percentage_change_cp
# Ticker        SAIL.NS
# Date
# 2005-02-18  40.597099                  NaN
# 2005-02-21  40.149216            -0.011032
# 2005-02-22  40.821033             0.016733
# 2005-02-23  40.661072            -0.003919
# 2005-02-24  40.629086            -0.000787

# %%
plot_graph((15,5),steel_authority['percentage_change_cp'],'percentage_change_cp')

# %%
Close_price= steel_authority[['Close']]

# %%
max(Close_price.values),min(Close_price.values)
# Out:
# (array([200.61054993]), array([17.53462791]))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(Close_price)
scaled_data
# Out:
# array([[0.12597217],
#        [0.12352573],
#        [0.12719535],
#        ...,
#        [0.48163281],
#        [0.47955719],
#        [0.47442269]])

# %%
len(scaled_data)
# Out:
# 4938

# %%
x_data =[]
y_data =[]

for i in range(100,len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])

import numpy as np
x_data, y_data =np.array(x_data), np.array(y_data)

# %%
x_data[0],y_data[0]
# Out:
# (array([[0.12597217],
#         [0.12352573],
#         [0.12719535],
#         [0.1263216 ],
#         [0.12614689],
#         [0.12474893],
#         [0.13313662],
#         [0.12684587],
#         [0.13383559],
#         [0.13698099],
#         [0.13680627],
#         [0.13855368],
#         [0.13663152],
#         [0.13016595],
#         [0.12946699],
#         [0.13453457],
#         [0.1373305 ],
#         [0.13645678],
#         [0.14239807],
#         [0.13156393],
#         [0.14222329],
#         [0.1439707 ],
#         [0.13453457],
#         [0.12702061],
#         [0.12719535],
#         [0.13051547],
#         [0.12387521],
#         [0.12072987],
#         [0.12527316],
#         [0.12981648],
#         [0.12509843],
#         [0.12160353],
#         [0.12894275],
#         [0.12614689],
#         [0.12404992],
#         [0.12457415],
#         [0.12737004],
#         [0.12282675],
#         [0.10937147],
#         [0.09416871],
#         [0.09486771],
#         [0.09818783],
#         [0.10185743],
#         [0.10080901],
#         [0.09853727],
#         [0.0955667 ],
#         [0.09364452],
#         [0.09294553],
#         [0.08945067],
#         [0.08892644],
#         [0.08857693],
#         [0.08927592],
#         [0.09207183],
#         [0.09259606],
#         [0.0934698 ],
#         [0.09521719],
#         [0.09014958],
#         [0.08980011],
#         [0.08892644],
#         [0.08840219],
#         [0.08263564],
#         [0.08368414],
#         [0.08403361],
#         [0.08001446],
#         [0.07424794],
#         [0.08665472],
#         [0.09294553],
#         [0.09294553],
#         [0.0934698 ],
#         [0.09381923],
#         [0.09504241],
#         [0.08752847],
#         [0.08281039],
#         [0.08315989],
#         [0.08420835],
#         [0.08420835],
#         [0.08281039],
#         [0.08438302],
#         [0.08368414],
#         [0.08281039],
#         [0.08368414],
#         [0.08630529],
#         [0.08840219],
#         [0.08927592],
#         [0.08980011],
#         [0.09189703],
#         [0.0880527 ],
#         [0.08717897],
#         [0.08630529],
#         [0.08123768],
#         [0.07564589],
#         [0.07756805],
#         [0.07232574],
#         [0.07337426],
#         [0.07494692],
#         [0.07547117],
#         [0.08018924],
#         [0.07983973],
#         [0.08281039],
#         [0.0891012 ]]),
#  array([0.0868295]))

# %%
int(len(x_data)*0.7)
# Out:
# 3386

# %%
4939-100-int(len(x_data)*0.7)
# Out:
# 1453

# %%
splitting_len =int(len(x_data)*0.7)
x_train =x_data [:splitting_len]
y_train =y_data [:splitting_len]

x_test =x_data [splitting_len:]
y_test =y_data [splitting_len:]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3386, 100, 1)
# (3386, 1)
# (1452, 100, 1)
# (1452, 1)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\vijay\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vijay\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\vijay\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\vijay\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\vijay\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vijay\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijay\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vijay\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijay\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vijay\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vijay\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vijay\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vijay\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vijay\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vijay\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vijay\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\vijay\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: absl-py in c:\users\vijay\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\vijay\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\vijay\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\vijay\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\vijay\anaconda3\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\vijay\anaconda3\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\vijay\anaconda3\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\vijay\anaconda3\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\vijay\anaconda3\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vijay\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vijay\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vijay\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# c:\Users\vijay\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(x_train,y_train,batch_size=1,epochs=2)
# Out:
# Epoch 1/2
# 3386/3386 ━━━━━━━━━━━━━━━━━━━━ 122s 35ms/step - loss: 0.0055
# Epoch 2/2
# 3386/3386 ━━━━━━━━━━━━━━━━━━━━ 121s 36ms/step - loss: 6.4282e-04

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
predictions = model.predict(x_test)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step

# %%
predictions
# Out:
# array([[0.15781754],
#        [0.15832177],
#        [0.15831667],
#        ...,
#        [0.49871668],
#        [0.47906908],
#        [0.47586346]], dtype=float32)

# %%
inv_predictions = scaler.inverse_transform(predictions)
inv_predictions
# Out:
# array([[ 46.42722 ],
#        [ 46.51953 ],
#        [ 46.518597],
#        ...,
#        [108.83765 ],
#        [105.24064 ],
#        [104.65377 ]], dtype=float32)

# %%
y_test
# Out:
# array([[0.17687824],
#        [0.17618502],
#        [0.17202587],
#        ...,
#        [0.48163281],
#        [0.47955719],
#        [0.47442269]])

# %%
inv_y_test = scaler.inverse_transform(y_test)
inv_y_test
# Out:
# array([[ 49.91677475],
#        [ 49.78986359],
#        [ 49.02842331],
#        ...,
#        [105.70999908],
#        [105.33000183],
#        [104.38999939]])

# %%
rmse = np.sqrt(np.mean((inv_predictions - inv_y_test)**2))

# %%
rmse
# Out:
# 3.4867799223691374

# %%
ploting_data = pd.DataFrame(
    {
        'original_test_data':inv_y_test.reshape(-1),
        'predictions': inv_predictions.reshape(-1)
    },
    index = steel_authority.index[splitting_len+100:]
)
ploting_data.head()
# Out:
#             original_test_data  predictions
# Date
# 2019-04-08           49.916775    46.427219
# 2019-04-09           49.789864    46.519531
# 2019-04-10           49.028423    46.518597
# 2019-04-11           48.013176    46.012714
# 2019-04-12           48.224689    45.196701

# %%
plot_graph((15,6),ploting_data,'test data')

# %%
plot_graph((15,6),pd.concat([Close_price[:splitting_len+100],ploting_data],axis=0),'whole data')

# %%
model.save("Latest_stock_price_model.keras")
